# %% [markdown]
# ### Regression Analysis

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn import preprocessing

import statsmodels.api as sm

# %%
import json

# %%
evaluate_cate = ['anger',
 'anticipation',
 'disgust',
 'fear',
 'joy',
 'negative',
 'positive',
 'sadness',
 'surprise',
 'trust']
evaluation = evaluate_cate[6]

agency = 'CFPB'

# %%
f = open("./emotion_dict_" + agency + ".json","r")

# %%
dict_OCC = json.load(f)

# %%
def get_emotion_df(evaluation, dict_OCC):
    dict_ = {}
    for key in dict_OCC.keys():
        empty_1 = 0
        try:
            rule_count = dict_OCC[key]['Rule'][evaluation][0]
        except:
            rule_count = 0
        pro_rule_count = 0
        comment_count = 0
        for pro_rule in dict_OCC[key]['Proposed Rule'].keys():
            try:
                pro_rule_count += dict_OCC[key]['Proposed Rule'][pro_rule][evaluation][0]
            except:
                pro_rule_count += 0
                empty_1 += 1

            try:
                comment_array = np.array(dict_OCC[key]['Proposed Rule'][pro_rule]['comment'][evaluation])
            except:
                comment_array = np.zeros(1)
            comment_array = comment_array[comment_array != 0]
            comment_count += np.mean(comment_array)

        comment_count = comment_count / len(dict_OCC[key]['Proposed Rule'])
        try:
            pro_rule_count = pro_rule_count / (len(dict_OCC[key]['Proposed Rule']) - empty_1)
        except:
            pro_rule_count = 0

        dict_[key] = [rule_count, pro_rule_count, comment_count]
    
    df = pd.DataFrame.from_dict(dict_, orient='index', columns = ['Rule ' + evaluation, 'Proposed Rule ' + evaluation, 'Comment ' + evaluation])
        
    return df

# %%
df = get_emotion_df(evaluation, dict_OCC)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df
# Out:
#                   Rule positive  Proposed Rule positive  Comment positive
# CFPB-2012-0039         0.068270                0.067127          0.067401
# CFPB-2012-0037         0.043513                0.041551          0.032651
# CFPB-2012-0031         0.036886                0.038772          0.035410
# CFPB-2013-0009         0.036230                0.033834          0.043408
# CFPB-2014-0024         0.034680                0.034853          0.041035
# OCC-2012-0013          0.036886                0.038717          0.041871
# CFPB-2017-0021         0.035984                0.040903          0.045761
# CFPB-2014-0031         0.052608                0.023738               NaN
# CFPB-2014-0009         0.045623                0.000000          0.049476
# CFPB-2013-0013         0.045496                0.045898          0.054380
# HUD-2013-0093          0.055632                0.054460          0.049705
# RHS-18-SFH-0020        0.041466                0.045412          0.052902
# CFPB-2012-0022         0.000000                0.032043          0.041188
# CFPB-2015-0006         0.042151                0.039808          0.041556
# CFPB-2012-0046         0.050810                0.052608          0.053047
# CFPB-2012-0015         0.045566                0.046961          0.049617
# OCC-2013-0009          0.043242                0.039296          0.048603
# CFPB-2012-0023         0.054571                0.049015          0.053087
# CFPB-2016-0038         0.041499                0.040889               NaN
# CFPB-2012-0005         0.000000                0.030340          0.040512
# CFPB-2011-0023         0.000000                0.049779               NaN
# CFPB-2012-0033         0.052482                0.052626               NaN
# CFPB-2012-0034         0.046113                0.046308          0.038598
# OCC-2014-0002          0.034366                0.033175          0.038107
# CFPB-2012-0050         0.041377                0.038053          0.044625
# CFPB-2012-0032         0.036401                0.038481          0.048691
# CFPB-2015-0029         0.047780                0.040380               NaN
# CFPB-2017-0008         0.044242                0.043887          0.043530
# CFPB-2017-0030         0.049548                0.046606          0.054222
# VA-2015-VBA-0004       0.031604                0.030952          0.011299
# CFPB-2017-0009         0.044216                0.042322          0.045814
# CFPB-2014-0010         0.052783                0.045520               NaN
# CFPB-2013-0005         0.033525                0.035285          0.038549
# CFPB-2013-0002         0.053717                0.052040          0.052081
# CFPB-2014-0028         0.041393                0.041581          0.043986
# CFPB-2013-0020         0.043242                0.000000          0.048184
# CFPB-2013-0018         0.046939                0.045839          0.043953
# CFPB-2014-0003         0.046562                0.045098          0.051845
# OCC-2015-0021          0.024687                0.030532          0.039488
# CFPB-2017-0015         0.049506                0.049498          0.044456
# CFPB-2013-0010         0.023102                0.050953          0.049630
# CFPB-2014-0033         0.032394                0.048510          0.041423
# CFPB-2012-0021         0.039563                0.036980          0.050647
# CFPB-2011-0009         0.026328                0.034397          0.039089
# CFPB-2012-0010         0.061666                0.056747          0.063348
# CFPB-2015-0004         0.041748                0.039835          0.051015
# OCC-2017-0008          0.036225                0.034848          0.053574
# CFPB-2011-0008         0.054495                0.050660          0.029875

# %%
x_factor = 'Proposed Rule ' + evaluation 
y_factor = 'Comment ' + evaluation 

scale = True

# %%
df.replace(0, np.nan, inplace=True)
df.dropna(inplace=True)

# %%
df
# Out:
#                   Rule positive  Proposed Rule positive  Comment positive
# CFPB-2012-0039         0.068270                0.067127          0.067401
# CFPB-2012-0037         0.043513                0.041551          0.032651
# CFPB-2012-0031         0.036886                0.038772          0.035410
# CFPB-2013-0009         0.036230                0.033834          0.043408
# CFPB-2014-0024         0.034680                0.034853          0.041035
# OCC-2012-0013          0.036886                0.038717          0.041871
# CFPB-2017-0021         0.035984                0.040903          0.045761
# CFPB-2013-0013         0.045496                0.045898          0.054380
# HUD-2013-0093          0.055632                0.054460          0.049705
# RHS-18-SFH-0020        0.041466                0.045412          0.052902
# CFPB-2015-0006         0.042151                0.039808          0.041556
# CFPB-2012-0046         0.050810                0.052608          0.053047
# CFPB-2012-0015         0.045566                0.046961          0.049617
# OCC-2013-0009          0.043242                0.039296          0.048603
# CFPB-2012-0023         0.054571                0.049015          0.053087
# CFPB-2012-0034         0.046113                0.046308          0.038598
# OCC-2014-0002          0.034366                0.033175          0.038107
# CFPB-2012-0050         0.041377                0.038053          0.044625
# CFPB-2012-0032         0.036401                0.038481          0.048691
# CFPB-2017-0008         0.044242                0.043887          0.043530
# CFPB-2017-0030         0.049548                0.046606          0.054222
# VA-2015-VBA-0004       0.031604                0.030952          0.011299
# CFPB-2017-0009         0.044216                0.042322          0.045814
# CFPB-2013-0005         0.033525                0.035285          0.038549
# CFPB-2013-0002         0.053717                0.052040          0.052081
# CFPB-2014-0028         0.041393                0.041581          0.043986
# CFPB-2013-0018         0.046939                0.045839          0.043953
# CFPB-2014-0003         0.046562                0.045098          0.051845
# OCC-2015-0021          0.024687                0.030532          0.039488
# CFPB-2017-0015         0.049506                0.049498          0.044456
# CFPB-2013-0010         0.023102                0.050953          0.049630
# CFPB-2014-0033         0.032394                0.048510          0.041423
# CFPB-2012-0021         0.039563                0.036980          0.050647
# CFPB-2011-0009         0.026328                0.034397          0.039089
# CFPB-2012-0010         0.061666                0.056747          0.063348
# CFPB-2015-0004         0.041748                0.039835          0.051015
# OCC-2017-0008          0.036225                0.034848          0.053574
# CFPB-2011-0008         0.054495                0.050660          0.029875

# %%
len(df)
# Out:
# 38

# %%
x = np.array(df[x_factor])[:,np.newaxis]
y = np.array(df[y_factor])[:,np.newaxis]

# %%
# df_positive = get_emotion_df('positive', dict_OCC)
# df_negative = get_emotion_df('negative', dict_OCC)

# x = np.array(df_positive['Proposed Rule positive'])[:,np.newaxis]
# y = np.array(df_negative ['Proposed Rule negative'])[:,np.newaxis]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
if scale:
    x = min_max_scaler.fit_transform(x)
    y = min_max_scaler.fit_transform(y)

# %%
ax = sns.regplot(x=x, y=y)
ax.set_xlabel(x_factor )
ax.set_ylabel(y_factor )
ax.set_title(evaluation)
plt.show()

# %%
est = sm.OLS(y, x)
est2 = est.fit()
print(est2.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.818
# Model:                            OLS   Adj. R-squared (uncentered):              0.813
# Method:                 Least Squares   F-statistic:                              166.0
# Date:                Fri, 04 Dec 2020   Prob (F-statistic):                    3.03e-15
# Time:                        15:37:48   Log-Likelihood:                         -4.1497
# No. Observations:                  38   AIC:                                      10.30
# Df Residuals:                      37   BIC:                                      11.94
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.4083      0.109     12.882      0.000       1.187       1.630
# ==============================================================================
# Omnibus:                        0.800   Durbin-Watson:                   1.459
# Prob(Omnibus):                  0.670   Jarque-Bera (JB):                0.842
# Skew:                          -0.306   Prob(JB):                        0.656
# Kurtosis:                       2.604   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
r_sq = model.score(x, y)
print('R^2', r_sq)

print('intercept:', model.intercept_)

print('slope:', model.coef_)
# Out:
# R^2 0.34733670931757354
# intercept: [0.44700137]
# slope: [[0.4686128]]

# %%
# evaluate_cate = ['anger',
#  'anticipation',
#  'disgust',
#  'fear',
#  'joy',
#  'negative',
#  'positive',
#  'sadness',
#  'surprise',
#  'trust']

# %%
# df_positive = get_emotion_df('positive', dict_OCC)
# df_negative = get_emotion_df('negative', dict_OCC)
